# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Entorno KRONOS operativo")
print(f"pandas {pd.__version__} | numpy {np.__version__}")
# Out:
# Entorno KRONOS operativo
# pandas 2.3.3 | numpy 2.4.4
# Executing <Handle BaseAsyncIOLoop._handle_events(1052, 1) created at C:\Users\mauri\AppData\Local\Programs\Python\Python311\Lib\asyncio\selector_events.py:267> took 0.172 seconds
